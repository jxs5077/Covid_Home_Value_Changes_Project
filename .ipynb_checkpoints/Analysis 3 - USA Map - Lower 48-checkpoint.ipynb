# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
# Store filepath in a variable
file_one = "output_data/us-states.txt"
us_states = pd.read_csv(file_one)

# %%
#Use grouby method on state
grouped = us_states.groupby(['state'])

# %%
#Find maximum amount of covid cases
max_cases = grouped['cases'].max()

# %%
#Drop US territories
remove_terr = pd.DataFrame(max_cases) 
fifty_states = remove_terr.drop(['Guam', 'Puerto Rico', 'Northern Mariana Islands', 'Virgin Islands', 'District of Columbia', 'Alaska', 'Hawaii'])

# %%
#Reset index
index_update = fifty_states.reset_index()
# index_update.head()

# %%
#Rename column, preparing for merge
rename_column = index_update.rename(columns={"state": "NAME", "cases":"Max_cases"})
# rename_column.head()

# %%
#File path for states data, includes coordinates
file_two = "output_data/States.csv"
state_info = pd.read_csv(file_two)
# state_info.head()

# %%
#merge data frames on like column
merge_state_dfs = pd.merge(rename_column, state_info, on="NAME", how="left")
# merge_state_dfs.head()

# %%
#Export to csv file for later use
merge_state_dfs.to_csv(r'output_data/state_data_new.csv', index=False)

# %%
#Read into shapefile from US census data
file_path = "mapping/us_nation/cb_2018_us_state_20m.shp"
usa_map = gpd.read_file(file_path)
# type(usa_map)

# %%
usa_map.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS          NAME LSAD  \
# 0      24  01714934  0400000US24    24     MD      Maryland   00
# 1      19  01779785  0400000US19    19     IA          Iowa   00
# 2      10  01779781  0400000US10    10     DE      Delaware   00
# 3      39  01085497  0400000US39    39     OH          Ohio   00
# 4      42  01779798  0400000US42    42     PA  Pennsylvania   00
#
#           ALAND       AWATER  \
# 0   25151100280   6979966958
# 1  144661267977   1084180812
# 2    5045925646   1399985648
# 3  105828882568  10268850702
# 4  115884442321   3394589990
#
#                                             geometry
# 0  MULTIPOLYGON (((-76.04621 38.02553, -76.00734 ...
# 1  POLYGON ((-96.62187 42.77925, -96.57794 42.827...
# 2  POLYGON ((-75.77379 39.72220, -75.75323 39.757...
# 3  MULTIPOLYGON (((-82.86334 41.69369, -82.82572 ...
# 4  POLYGON ((-80.51989 40.90666, -80.51964 40.987...

# %%
#Drop AK and HI
lower_48 = usa_map.loc[~usa_map['NAME'].isin(['Alaska', 'Hawaii', 'Puerto Rico'])]

# %%
#Read csv file
# Store filepath in a variable
file_three = "output_data/state_data_new.csv"
states_info = pd.read_csv(file_three)

# %%
#Merge state data with shape file
merge_data=usa_map.merge(states_info,on='NAME')
#merge_data

# %%
#Attempt to plot data with map
ax = merge_data.plot(column='Max_cases',figsize=(35, 20),cmap='Reds',legend=True)
plt.xlim(-130,-60)
plt.ylim(20,55)

#Include state names
for abbr in range(len(merge_data)):
    plt.text(merge_data.lng[abbr],
             merge_data.lat[abbr],
             "{}\n{}".format(merge_data.NAME[abbr],
             merge_data.Max_cases[abbr]),size=12)
plt.title('Maximum COVID-19 Cases per State (showing lower forty-eight)',fontsize=50)
ax.axis('off')
plt.show()
